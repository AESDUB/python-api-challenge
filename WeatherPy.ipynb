# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import os


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    city = city.replace(" ","+")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
City = []
Country = []
Cloudiness = []
Date = []
Humidity = []
Lat = []
Lon = []
Max_Temp = []
Wind_Speed = []

count_record = 1
units = "metric"


base_url = "http://api.openweathermap.org/data/2.5/weather?"
for c in cities:
    try:
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        # Starting with the url and getting it to append to each city
        query_url = f"{base_url}appid={api_key}&units={units}&q={c}"
        response = requests.get(query_url).json()
        print(f"Sanity Checking the URL\n{query_url}")
        
        # Appending each list as declared above
        City.append(response['name'])
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lon.append(response['coord']['lat'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        
        c_fixed = c.replace("+"," ")
        
        print(f"\nRecord {record_count} of Set 1 | {c_fixed}")
        print("--------------------------")
        
        # Adding up on the record
        record_count += 1
        

        time.sleep(1.5)
    except:
#         c_fixed = c.replace("+"," ")
        print(f"\nWas not found: {c}")
        print("--------------------------")
    continue
# Out:
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kodiak
#
# Was not found: kodiak
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=airai
#
# Was not found: airai
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=santa+barbara
#
# Was not found: santa+barbara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pisco
#
# Was not found: pisco
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mataura
#
# Was not found: mataura
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=albany
#
# Was not found: albany
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=port+elizabeth
#
# Was not found: port+elizabeth
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dongying
#
# Was not found: dongying
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=upernavik
#
# Was not found: upernavik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mae+sai
#
# Was not found: mae+sai
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=norman+wells
#
# Was not found: norman+wells
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bengkulu
#
# Was not found: bengkulu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=new+norfolk
#
# Was not found: new+norfolk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=vila+velha
#
# Was not found: vila+velha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=isabela
#
# Was not found: isabela
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=illoqqortoormiut
#
# Was not found: illoqqortoormiut
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=muros
#
# Was not found: muros
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=atuona
#
# Was not found: atuona
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kokstad
#
# Was not found: kokstad
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=karratha
#
# Was not found: karratha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ust-kut
#
# Was not found: ust-kut
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=nikolskoye
#
# Was not found: nikolskoye
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ossora
#
# Was not found: ossora
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=yellowknife
#
# Was not found: yellowknife
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=wolmaranstad
#
# Was not found: wolmaranstad
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tsihombe
#
# Was not found: tsihombe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=saskylakh
#
# Was not found: saskylakh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=butaritari
#
# Was not found: butaritari
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mount+isa
#
# Was not found: mount+isa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kapaa
#
# Was not found: kapaa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bilibino
#
# Was not found: bilibino
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ushuaia
#
# Was not found: ushuaia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=high+level
#
# Was not found: high+level
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kaitangata
#
# Was not found: kaitangata
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hilo
#
# Was not found: hilo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=burnie
#
# Was not found: burnie
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=vardo
#
# Was not found: vardo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=beli+potok
#
# Was not found: beli+potok
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ketchikan
#
# Was not found: ketchikan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kutum
#
# Was not found: kutum
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=samusu
#
# Was not found: samusu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sioux+lookout
#
# Was not found: sioux+lookout
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=acapulco
#
# Was not found: acapulco
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=barrow
#
# Was not found: barrow
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=nizhneyansk
#
# Was not found: nizhneyansk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=palmer
#
# Was not found: palmer
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=we
#
# Was not found: we
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sola
#
# Was not found: sola
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=east+london
#
# Was not found: east+london
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=punta+arenas
#
# Was not found: punta+arenas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=grindavik
#
# Was not found: grindavik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mount+gambier
#
# Was not found: mount+gambier
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=thompson
#
# Was not found: thompson
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=busselton
#
# Was not found: busselton
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=cherskiy
#
# Was not found: cherskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=qrendi
#
# Was not found: qrendi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=aasiaat
#
# Was not found: aasiaat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ulsteinvik
#
# Was not found: ulsteinvik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=celestun
#
# Was not found: celestun
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=zhangye
#
# Was not found: zhangye
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ostrovnoy
#
# Was not found: ostrovnoy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=marcona
#
# Was not found: marcona
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=constitucion
#
# Was not found: constitucion
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=turayf
#
# Was not found: turayf
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hermanus
#
# Was not found: hermanus
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tuatapere
#
# Was not found: tuatapere
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=iqaluit
#
# Was not found: iqaluit
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=lebu
#
# Was not found: lebu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=esperance
#
# Was not found: esperance
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=northam
#
# Was not found: northam
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=arraial+do+cabo
#
# Was not found: arraial+do+cabo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mar+del+plata
#
# Was not found: mar+del+plata
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=zheleznodorozhnyy
#
# Was not found: zheleznodorozhnyy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tromso
#
# Was not found: tromso
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=oranjemund
#
# Was not found: oranjemund
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mentok
#
# Was not found: mentok
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=qaanaaq
#
# Was not found: qaanaaq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=rikitea
#
# Was not found: rikitea
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=derzhavinsk
#
# Was not found: derzhavinsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ondorhaan
#
# Was not found: ondorhaan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=jamestown
#
# Was not found: jamestown
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sataua
#
# Was not found: sataua
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=harper
#
# Was not found: harper
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=marzuq
#
# Was not found: marzuq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=svetlogorsk
#
# Was not found: svetlogorsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=warmbad
#
# Was not found: warmbad
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kirakira
#
# Was not found: kirakira
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bluff
#
# Was not found: bluff
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=itaqui
#
# Was not found: itaqui
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hithadhoo
#
# Was not found: hithadhoo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=piacabucu
#
# Was not found: piacabucu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dzhebariki-khaya
#
# Was not found: dzhebariki-khaya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mahebourg
#
# Was not found: mahebourg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sao+joao+da+barra
#
# Was not found: sao+joao+da+barra
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bambous+virieux
#
# Was not found: bambous+virieux
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=antofagasta
#
# Was not found: antofagasta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=vila+franca+do+campo
#
# Was not found: vila+franca+do+campo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pevek
#
# Was not found: pevek
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bolungarvik
#
# Was not found: bolungarvik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ahipara
#
# Was not found: ahipara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=san+nicolas
#
# Was not found: san+nicolas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=diapaga
#
# Was not found: diapaga
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=port+hardy
#
# Was not found: port+hardy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=torbay
#
# Was not found: torbay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=port+alfred
#
# Was not found: port+alfred
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=olinda
#
# Was not found: olinda
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pirdop
#
# Was not found: pirdop
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kavieng
#
# Was not found: kavieng
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hofn
#
# Was not found: hofn
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pangnirtung
#
# Was not found: pangnirtung
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=puerto+suarez
#
# Was not found: puerto+suarez
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hobart
#
# Was not found: hobart
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=souillac
#
# Was not found: souillac
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=castro
#
# Was not found: castro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=itarema
#
# Was not found: itarema
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=nanortalik
#
# Was not found: nanortalik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=georgetown
#
# Was not found: georgetown
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bella+vista
#
# Was not found: bella+vista
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=barentsburg
#
# Was not found: barentsburg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kidodi
#
# Was not found: kidodi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=biloela
#
# Was not found: biloela
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kavaratti
#
# Was not found: kavaratti
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=khatanga
#
# Was not found: khatanga
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=yar-sale
#
# Was not found: yar-sale
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=carnarvon
#
# Was not found: carnarvon
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=saint+george
#
# Was not found: saint+george
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=anadyr
#
# Was not found: anadyr
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=akropong
#
# Was not found: akropong
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=rocha
#
# Was not found: rocha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=iquique
#
# Was not found: iquique
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sisimiut
#
# Was not found: sisimiut
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sao+filipe
#
# Was not found: sao+filipe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kathu
#
# Was not found: kathu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=la+rioja
#
# Was not found: la+rioja
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=avarua
#
# Was not found: avarua
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ilulissat
#
# Was not found: ilulissat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bethel
#
# Was not found: bethel
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dryden
#
# Was not found: dryden
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=taolanaro
#
# Was not found: taolanaro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=asbury+park
#
# Was not found: asbury+park
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=exeter
#
# Was not found: exeter
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tiksi
#
# Was not found: tiksi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=berlevag
#
# Was not found: berlevag
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=noblesville
#
# Was not found: noblesville
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=aras
#
# Was not found: aras
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bubaque
#
# Was not found: bubaque
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=san+patricio
#
# Was not found: san+patricio
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=itoman
#
# Was not found: itoman
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tuktoyaktuk
#
# Was not found: tuktoyaktuk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=avera
#
# Was not found: avera
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=provideniya
#
# Was not found: provideniya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=honiara
#
# Was not found: honiara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=enid
#
# Was not found: enid
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=alassio
#
# Was not found: alassio
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mehtar+lam
#
# Was not found: mehtar+lam
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=patitirion
#
# Was not found: patitirion
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=limon
#
# Was not found: limon
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=severo-kurilsk
#
# Was not found: severo-kurilsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=opuwo
#
# Was not found: opuwo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bredasdorp
#
# Was not found: bredasdorp
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=linchuan
#
# Was not found: linchuan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=chuy
#
# Was not found: chuy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=caiaponia
#
# Was not found: caiaponia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ibadan
#
# Was not found: ibadan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dodge+city
#
# Was not found: dodge+city
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sentyabrskiy
#
# Was not found: sentyabrskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=fortuna
#
# Was not found: fortuna
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ponta+do+sol
#
# Was not found: ponta+do+sol
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=praya
#
# Was not found: praya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=abu+samrah
#
# Was not found: abu+samrah
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=amderma
#
# Was not found: amderma
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=isangel
#
# Was not found: isangel
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=guerrero+negro
#
# Was not found: guerrero+negro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=shchelyayur
#
# Was not found: shchelyayur
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=santa+catarina+de+tepehuanes
#
# Was not found: santa+catarina+de+tepehuanes
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=birao
#
# Was not found: birao
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=nelson+bay
#
# Was not found: nelson+bay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pio+ix
#
# Was not found: pio+ix
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dikson
#
# Was not found: dikson
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=cao+bang
#
# Was not found: cao+bang
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=cape+town
#
# Was not found: cape+town
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kabansk
#
# Was not found: kabansk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=caravelas
#
# Was not found: caravelas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=jalu
#
# Was not found: jalu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=piranhas
#
# Was not found: piranhas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dawei
#
# Was not found: dawei
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=brazzaville
#
# Was not found: brazzaville
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=petropavlovsk-kamchatskiy
#
# Was not found: petropavlovsk-kamchatskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bathsheba
#
# Was not found: bathsheba
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=antalaha
#
# Was not found: antalaha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=aitape
#
# Was not found: aitape
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ust-kamchatsk
#
# Was not found: ust-kamchatsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=male
#
# Was not found: male
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=henties+bay
#
# Was not found: henties+bay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=longyearbyen
#
# Was not found: longyearbyen
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=cap-aux-meules
#
# Was not found: cap-aux-meules
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bandarbeyla
#
# Was not found: bandarbeyla
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=liniere
#
# Was not found: liniere
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=akhmim
#
# Was not found: akhmim
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=narsaq
#
# Was not found: narsaq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tomatlan
#
# Was not found: tomatlan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=fevralsk
#
# Was not found: fevralsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dalbandin
#
# Was not found: dalbandin
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=puerto+ayora
#
# Was not found: puerto+ayora
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=giaveno
#
# Was not found: giaveno
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=havoysund
#
# Was not found: havoysund
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=geraldton
#
# Was not found: geraldton
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=malaya+purga
#
# Was not found: malaya+purga
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=alyangula
#
# Was not found: alyangula
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sur
#
# Was not found: sur
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=komsomolskiy
#
# Was not found: komsomolskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=lavrentiya
#
# Was not found: lavrentiya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=belaya+gora
#
# Was not found: belaya+gora
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=darhan
#
# Was not found: darhan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=comodoro+rivadavia
#
# Was not found: comodoro+rivadavia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=chaykovskiy
#
# Was not found: chaykovskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=izhma
#
# Was not found: izhma
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=turbat
#
# Was not found: turbat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ramshir
#
# Was not found: ramshir
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=beringovskiy
#
# Was not found: beringovskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=saint-philippe
#
# Was not found: saint-philippe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=alotau
#
# Was not found: alotau
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pemangkat
#
# Was not found: pemangkat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=olga
#
# Was not found: olga
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kuvandyk
#
# Was not found: kuvandyk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tommot
#
# Was not found: tommot
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bolshegrivskoye
#
# Was not found: bolshegrivskoye
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=karaul
#
# Was not found: karaul
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mporokoso
#
# Was not found: mporokoso
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ngukurr
#
# Was not found: ngukurr
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=port-cartier
#
# Was not found: port-cartier
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ribeira+grande
#
# Was not found: ribeira+grande
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mys+shmidta
#
# Was not found: mys+shmidta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tasiilaq
#
# Was not found: tasiilaq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=assare
#
# Was not found: assare
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=soritor
#
# Was not found: soritor
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sorvag
#
# Was not found: sorvag
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tamana
#
# Was not found: tamana
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=margate
#
# Was not found: margate
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=alta+floresta
#
# Was not found: alta+floresta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=manokwari
#
# Was not found: manokwari
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=waipawa
#
# Was not found: waipawa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sun+valley
#
# Was not found: sun+valley
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kaeo
#
# Was not found: kaeo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=waingapu
#
# Was not found: waingapu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=attawapiskat
#
# Was not found: attawapiskat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=banda+aceh
#
# Was not found: banda+aceh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=aripuana
#
# Was not found: aripuana
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=polson
#
# Was not found: polson
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sungaipenuh
#
# Was not found: sungaipenuh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hermagor
#
# Was not found: hermagor
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=andenes
#
# Was not found: andenes
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kieta
#
# Was not found: kieta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=broken+hill
#
# Was not found: broken+hill
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=deloraine
#
# Was not found: deloraine
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tursunzoda
#
# Was not found: tursunzoda
# --------------------------
# Sanity Checking the URL
# ...
#
# Was not found: haverfordwest
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=gemena
#
# Was not found: gemena
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dharchula
#
# Was not found: dharchula
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=lincoln
#
# Was not found: lincoln
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=merauke
#
# Was not found: merauke
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=wattegama
#
# Was not found: wattegama
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=verkhnyaya+inta
#
# Was not found: verkhnyaya+inta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=fallon
#
# Was not found: fallon
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=zyryanka
#
# Was not found: zyryanka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=marienburg
#
# Was not found: marienburg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=cotacachi
#
# Was not found: cotacachi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=buala
#
# Was not found: buala
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=manjakandriana
#
# Was not found: manjakandriana
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=amboasary
#
# Was not found: amboasary
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hambantota
#
# Was not found: hambantota
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=uyutne
#
# Was not found: uyutne
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=huarmey
#
# Was not found: huarmey
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=savannah+bight
#
# Was not found: savannah+bight
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bababe
#
# Was not found: bababe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ampanihy
#
# Was not found: ampanihy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=severo-yeniseyskiy
#
# Was not found: severo-yeniseyskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sheopur
#
# Was not found: sheopur
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=waidhofen
#
# Was not found: waidhofen
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=jarocin
#
# Was not found: jarocin
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=veydelevka
#
# Was not found: veydelevka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=buraydah
#
# Was not found: buraydah
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=manoharpur
#
# Was not found: manoharpur
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ak-dovurak
#
# Was not found: ak-dovurak
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=santa+rosa
#
# Was not found: santa+rosa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kuche
#
# Was not found: kuche
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dudinka
#
# Was not found: dudinka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=karakendzha
#
# Was not found: karakendzha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tilichiki
#
# Was not found: tilichiki
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=palabuhanratu
#
# Was not found: palabuhanratu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=rabaul
#
# Was not found: rabaul
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=lexington
#
# Was not found: lexington
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=yerbogachen
#
# Was not found: yerbogachen
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=galashki
#
# Was not found: galashki
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=barahona
#
# Was not found: barahona
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=cookeville
#
# Was not found: cookeville
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sunland+park
#
# Was not found: sunland+park
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=borujan
#
# Was not found: borujan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=verkhnevilyuysk
#
# Was not found: verkhnevilyuysk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tessalit
#
# Was not found: tessalit
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=eskasem
#
# Was not found: eskasem
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=krasnokamensk
#
# Was not found: krasnokamensk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=gazanjyk
#
# Was not found: gazanjyk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=salinas
#
# Was not found: salinas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=pacific+grove
#
# Was not found: pacific+grove
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=chamba
#
# Was not found: chamba
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=dingle
#
# Was not found: dingle
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ilhabela
#
# Was not found: ilhabela
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=hovd
#
# Was not found: hovd
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=kourou
#
# Was not found: kourou
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bemidji
#
# Was not found: bemidji
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=vung+tau
#
# Was not found: vung+tau
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=yarada
#
# Was not found: yarada
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=marsh+harbour
#
# Was not found: marsh+harbour
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=severobaykalsk
#
# Was not found: severobaykalsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=lae
#
# Was not found: lae
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=sambava
#
# Was not found: sambava
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=san+rafael
#
# Was not found: san+rafael
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mahoba
#
# Was not found: mahoba
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=bull+savanna
#
# Was not found: bull+savanna
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=asau
#
# Was not found: asau
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tiznit
#
# Was not found: tiznit
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=ushtobe
#
# Was not found: ushtobe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=port+lincoln
#
# Was not found: port+lincoln
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=giyani
#
# Was not found: giyani
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=razdolinsk
#
# Was not found: razdolinsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=takaka
#
# Was not found: takaka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tautira
#
# Was not found: tautira
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=balasinor
#
# Was not found: balasinor
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=samarai
#
# Was not found: samarai
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=grand+baie
#
# Was not found: grand+baie
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=erdenet
#
# Was not found: erdenet
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=lodja
#
# Was not found: lodja
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=oeiras
#
# Was not found: oeiras
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=angra
#
# Was not found: angra
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=erenhot
#
# Was not found: erenhot
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=tahara
#
# Was not found: tahara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=port-gentil
#
# Was not found: port-gentil
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=natal
#
# Was not found: natal
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=mezen
#
# Was not found: mezen
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=windhoek
#
# Was not found: windhoek
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=38316d9098c25bce694a4600e8598711&units=metric&q=wangkui
#
# Was not found: wangkui
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame({
    "City":City,
    "Cloudiness":Cloudiness,
    "Country":Country,
    "Date":Date,
    "Humidity":Humidity,
    "Lat":Lat,
    "Lon":Lon,
    "Max_Temp":Max_Temp,
    "Wind_Speed":Wind_Speed})
df.count()

# %%
df.head()

# %%
df.to_csv("Cities_&_weather_stats.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# getting the current data
from datetime import datetime as dt
print(dt.today())

fig1, ax1 = plt.subplots()
latitude = df.Lat
temperature = df.Max_Temp
ax1.scatter(latitude, temperature, marker='o', edgecolors='black')
ax1.set_title(f"City Latitude vs. Max Temperature ({dt.today()})")
ax1.set_xlabel("City Latitude")
ax1.set_ylabel("Max Temperature ($^\circ$C)")
ax1.grid(axis='both')
fig1.savefig("Fig 1 - City Latitude vs. Max Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig2, ax2 = plt.subplots()
latitude = df.Lat
humidity = df.Humidity
ax2.scatter(latitude, humidity, marker='o', edgecolors='black')
ax2.set_title(f"City Latitude vs. Humidity ({dt.today()})")
ax2.set_xlabel("City Latitude")
ax2.set_ylabel("Humidity (%)")
ax2.grid(axis='both')
fig2.savefig(f"Fig 2 - City Latitude vs. Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig3, ax3 = plt.subplots()
latitude = df.Lat
cloudiness = df.Cloudiness
ax3.scatter(latitude, humidity, marker='o', edgecolors='black')
ax3.set_title(f"City Latitude vs. Cloudiness ({dt.today()})")
ax3.set_xlabel("City Latitude")
ax3.set_ylabel("Cloudiness (%)")
ax3.grid(axis='both')
fig3.savefig(f"Fig 3 - City Latitude vs. Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig4, ax4 = plt.subplots()
latitude = df.Lat
wind_speed = df.Wind_Speed
ax4.scatter(latitude, wind_speed, marker='o', edgecolors='black')
ax4.set_title(f"City Latitude vs. Wind Speed ({dt.today()})")
ax4.set_xlabel("City Latitude")
ax4.set_ylabel("Wind Speed (ms$^{-1}$)")
ax4.grid(axis='both')
fig4.savefig(f"Fig 4 - City Latitude vs Wind Speed)")
